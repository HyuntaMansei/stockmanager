# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import importlib
import os, sys
from pathlib import Path

p = str(Path(os.getcwd()).parent) + os.sep + 'mpykrx'
sys.path.insert(1, p)

# %%
import db_manager
import pykrx_manager

# %%
importlib.reload(db_manager)
importlib.reload(stock)
# Out:
# <module 'db_manager' from 'c:\\Users\\boringstock\\Coding\\Python\\stockmanager\\db_manager.py'>
# <module 'mpykrx.stock' from 'c:\\Users\\boringstock\\Coding\\Python\\mpykrx\\mpykrx\\stock\\__init__.py'>

# %%
dbm = db_manager.DbManager()
stock = pykrx_manager.stock

# %%
df = stock.get_modified_market_ohlcv_by_ticker("20230223", "ALL")
dbm.write_and_move_data_frame('daily_stock_price_tb', df)
# Out:
#         insert into daily_stock_price_tb (
#             stock_code, stock_name, market, department, open_price, high_price, low_price, close_price, cmpared_prev_price, fluctuation_rate, trading_volume, trading_value, listed_shared, created_date
#         )
#         select 티커, 종목명, 시장이름, 소속부, 시가, 고가, 저가, 종가, 전일대비, 등락률, 거래량, 거래대금, 상장주식수, now()
#         from temp_tb
#         on duplicate key update stock_code = values(stock_code), stock_name = values(stock_name), market = values(market), department = values(department), open_price = values(open_price), high_price = values(high_price), low_price = values(low_price), close_price = values(close_price), cmpared_prev_price = values(cmpared_prev_price), fluctuation_rate = values(fluctuation_rate), trading_volume = values(trading_volume), trading_value = values(trading_value), listed_shared = values(listed_shared), created_date = values(created_date), is_updated='y', updated_date=now()
# ...

# %%
df = stock.get_modified_market_ohlcv_by_ticker("20230223", "ALL")
df
# Out:
#             종목명    시장이름    소속부     시가     고가     저가     종가  전일대비   등락률  \
# 티커
# 060310       3S  KOSDAQ  중견기업부   2360   2365   2300   2315   -35 -1.49
# 095570   AJ네트웍스   KOSPI      0   5460   5490   5390   5460     0  0.00
# 006840    AK홀딩스   KOSPI      0  17630  17800  17600  17800   170  0.96
# 054620   APS홀딩스  KOSDAQ  중견기업부  13600  13760  13510  13760   160  1.18
# 265520    AP시스템  KOSDAQ  우량기업부  20250  20600  20250  20550   400  1.99
# ...         ...     ...    ...    ...    ...    ...    ...   ...   ...
# 000547  흥국화재2우B   KOSPI      0  19070  23000  19070  19620   550  2.88
# 000545    흥국화재우   KOSPI      0   6800   7300   6800   7060   220  3.22
# 003280     흥아해운   KOSPI      0   1525   1575   1519   1537    24  1.59
# 037440       희림  KOSDAQ  우량기업부   9980  10050   9840   9900  -100 -1.00
# 238490       힘스  KOSDAQ  우량기업부   6420   6420   6250   6380     0  0.00
#
#            거래량        거래대금      상장주식수
# 티커
# 060310  337023   783824005   48536642
# ...

# %%
dbm.write_and_move_data_frame('daily_stock_price_tb', df)
# Out:
# mysql+pymysql://super:aksaksgo1!@146.56.43.43:3306/stock
#
#             select to_column_name from data_matching_information_tb
#             where from_table_name = %s and from_column_name = %s and to_table_name = %s;
#
# ('temp_tb', '티커', 'daily_stock_price_tb')
#
#             select to_column_name from data_matching_information_tb
#             where from_table_name = %s and from_column_name = %s and to_table_name = %s;
#
# ('temp_tb', '종목명', 'daily_stock_price_tb')
#
#             select to_column_name from data_matching_information_tb
#             where from_table_name = %s and from_column_name = %s and to_table_name = %s;
#
# ('temp_tb', '시장이름', 'daily_stock_price_tb')
#
#             select to_column_name from data_matching_information_tb
#             where from_table_name = %s and from_column_name = %s and to_table_name = %s;
#
# ('temp_tb', '소속부', 'daily_stock_price_tb')
#
#             select to_column_name from data_matching_information_tb
# ...

# %%
dbm.close()
